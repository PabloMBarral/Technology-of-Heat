# %% [markdown]
# Empezamos importando las librerías que necesitamos.

# %%
import numpy as np
import pandas as pd

# %%
dolar = pd.read_excel("Dolar.xlsx", "Sheet1", na_values=["NA"])
dolar
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-1fc1780cd581> in <cell line: 1>()
# ----> 1 dolar = pd.read_excel("Dolar.xlsx", "Sheet1", na_values=["NA"])
#       2 dolar
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...
